# %%
import warnings
warnings.filterwarnings('ignore') # disable warnings relateds to versions of tf
import numpy as np
import dianna
import onnx
from onnx_tf.backend import prepare
import matplotlib.pyplot as plt
from pathlib import Path
from dianna import visualization
from keras import utils
import onnx
import onnxruntime
from scipy.special import softmax

def run_model(data, name):
    fname           = str(Path('models', name))
    sess            = onnxruntime.InferenceSession(fname)
    input_name      = sess.get_inputs()[0].name
    output_name     = sess.get_outputs()[0].name

    onnx_input      = {input_name: data}
    pred_onnx       = sess.run([output_name], onnx_input)

    return softmax(pred_onnx[0], axis=1)

DATA_PATH           = Path('data', 'shapes.npz')
MODEL_NAME          = 'geometric_shapes_model.onnx'
MODEL_PATH          = Path('models', MODEL_NAME)
# load dataset
data                = np.load(DATA_PATH)
# load testing data and the related labels
X_test              = data['X_test'].astype(np.float32).reshape([-1, 1, 64, 64])
y_test              = data['y_test']


# Load saved onnx model
onnx_model          = onnx.load(MODEL_PATH)
output_node         = prepare(onnx_model, gen_tensor_dict=True).outputs[0]
# pred_onnx           = run_model(X_test, MODEL_NAME)
# pred_ids            = pred_onnx.argmax(axis=1)
class_name          = ['circle', 'triangle']
# Out:
# 2024-01-17 11:53:40.537333: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2024-01-17 11:53:40.537356: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 32.00 GB
# 2024-01-17 11:53:40.537362: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 10.67 GB
# 2024-01-17 11:53:40.537398: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-01-17 11:53:40.537414: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
import pickle
with open(Path("data", "test_rotation.pk"), "rb") as f:
    data = pickle.load(f)

# %%
data['triangles']
# Out:
# array([{'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 0},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 1},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 2},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 3},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 4},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 5},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 6},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 7},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 8},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 9},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 10},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 11},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 12},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 13},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 14},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 15},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 16},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 17},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 18},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 19},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 20},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 21},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 22},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 23},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 24},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 25},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 26},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 27},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 28},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 29},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 30},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 31},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 32},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 33},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 34},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 35},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 36},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 37},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 38},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 39},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 40},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 41},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 42},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 43},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 44},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 45},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 46},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 47},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 48},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 49},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 50},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 51},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 52},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 53},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 54},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 55},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 56},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 57},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 58},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 59},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 60},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 61},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 62},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 63},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 64},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 65},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 66},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 67},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 68},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 69},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 70},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 71},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 72},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 73},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 74},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 75},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 76},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 77},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 78},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 79},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 80},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 81},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 82},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 83},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 84},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 85},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 86},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 87},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 88},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 89},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 90},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 91},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 92},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 93},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 94},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 95},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 96},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 97},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 98},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 99},
#        {'image': array([[255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               ...,
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255],
#               [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 'label': 1, 'roundness': -1, 'color': 0, 'angle': 100}],
#       dtype=object)

# %%
plt.imshow(data['triangles'][99]['image'])

# %%
imgs = np.array([data['triangles'][j]['image'] for j in range(data['triangles'].shape[0])]) / 255.0
imgs = imgs.astype(np.float32)

# %%
r_arr = []
rotated_onnx           = run_model(imgs[:, None, ...], MODEL_NAME)

# %%
rotated_ids            = rotated_onnx.argmax(axis=1)
for i_instance in range(len(imgs)):
    # select instance for testing
    test_sample     = imgs[i_instance].copy().astype(np.float32).reshape(1, 64, 64)
    # model predictions with added batch axis to test sample
    predictions     = prepare(onnx_model).run(test_sample[None, ...])[f'{output_node}']
    pred_class      = class_name[np.argmax(predictions)]
    print("The predicted class is:", pred_class, "No.", i_instance)
    relevances      = dianna.explain_image(MODEL_PATH, test_sample,
                                                  method="LIME", labels=[rotated_ids[i_instance]],
                                                  top_label = 1,
                                                  num_features = 10,
                                                  num_samples = 1000,
                                                #   nsamples=1000,
                                                #   n_masks=1000, feature_res=2, p_keep=0.7,
                                                #   axis_labels=('channels','height','width')
                                                )

    # relevances      = dianna.explain_image(MODEL_PATH, test_sample,
    #                                               method="RISE", labels=[rotated_ids[i_instance]],
    #                                               n_masks = 1000,
    #                                               feature_res = 8,
    #                                               p_keep = 0.9,
    #                                               axis_labels=('channels','height','width')
    #                                             )

    class_idx       = rotated_ids[i_instance]
    # fig, ax         = plt.subplots(1,3)
    # ax[0].imshow(relevances[0],cmap='jet')
    # ax[1].imshow(utils.img_to_array(test_sample[0])/255.,cmap='gray')
    # ax[2].imshow(utils.img_to_array(test_sample[0]) / 255., cmap='gray')
    # ax[2].imshow(relevances[0], cmap='jet', alpha=0.4)
    # plt.title(str(1)+'_'+str(rotated_onnx[i_instance,rotated_ids[i_instance]]))
    # plt.show()
    r_arr.append(relevances)
    # if i_instance > 2:
    #     break

# %%
# r_arr[90].max()

# %%
# tested with python3
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

def GetRotateMatrixWithCenter(x, y, angle):
    # https://math.stackexchange.com/questions/2093314
    move_matrix = np.array(
        [
            [1, 0, x], 
            [0, 1, y], 
            [0, 0, 1]
        ])
    rotation_matrix = np.array(
        [
            [np.cos(angle), -np.sin(angle), 0], 
            [np.sin(angle),  np.cos(angle), 0], 
            [0,                       0,                      1]
        ])
    back_matrix = np.array(
        [
            [1, 0, -x], 
            [0, 1, -y], 
            [0, 0, 1]
        ])

    r = np.dot(move_matrix, rotation_matrix)
    return np.dot(r, back_matrix)

def Apply_Matrix_To_Image(matrix_to_apply, image_map):
    #takes an image and matrices and applies it.  
    x_min = 0
    y_min = 0
    x_max = image_map.shape[0]
    y_max = image_map.shape[1] 

    new_image_map = np.zeros((x_max, y_max), dtype=int) + img.max()

    for y_counter in range(0, y_max):
        for x_counter in range(0, x_max):
            curr_pixel = [x_counter,y_counter,1]

            curr_pixel = np.dot(matrix_to_apply, curr_pixel)

            # print(curr_pixel)

            if curr_pixel[0] > x_max - 1 or curr_pixel[1] > y_max - 1 or x_min > curr_pixel[0] or y_min > curr_pixel[1]:
                next
            else:
                new_image_map[x_counter][y_counter] = image_map[int(curr_pixel[0])][int(curr_pixel[1])] 

    return new_image_map


# convert image to grayscale
img = r_arr[0][0]

image_width = img.shape[0]
image_height = img.shape[1] 

# plt.subplot(1,2,1)
# plt.title('Origin heatmap')
# plt.imshow(img, cmap='gray', vmin=0, vmax=1)

# plt.subplot(1,2,2)
# plt.title('Transformed image')


alpha = 0

rotated_imgs = []
for ind, alp in enumerate(range(len(imgs)-1)):
    rotation_angle = 0 + alp
    # alpha = alpha + 1 # increate 1 degree
    # if alpha > 120:
    #     break
    rotation_angle = np.deg2rad(rotation_angle) # degree to radian
    
    rotation_matrix = GetRotateMatrixWithCenter(image_width / 2, image_height / 2, rotation_angle)

    rotated = Apply_Matrix_To_Image(rotation_matrix, img)

    rotated_imgs.append(rotated)

    # plt.imshow(rotated, cmap='gray', vmin=0, vmax=1)
    plt.subplot(1,2,1)
    plt.title('Heatmap of the image (clockwise rotated '  +str(ind) +' deg)', fontsize=6)
    plt.imshow(r_arr[ind][0], cmap='gray', vmin=0, vmax=1)

    plt.subplot(1,2,2)
    plt.title('Heatmap of the image (clockwise rotated '  +str(ind+1) +' deg)', fontsize=6)
    plt.imshow(r_arr[ind+1][0], cmap='gray')
    plt.pause(0.001)
# plt.show()
