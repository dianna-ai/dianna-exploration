# %% [markdown]
# ## Movie review model generation
# This notebook handles the model generation for the movie review dataset.
# Before running this notebook, make sure to run the [data preparation notebook](./data_preparation.ipynb) to generate
# the word embeddings required for the model.
# In addition to [PyTorch](https://pytorch.org/docs/stable/index.html), this notebook depends on [torchtext](https://pytorch.org/text/stable/index.html) for handling the input data. The notebook is also linked to [Weights & Biases](wandb.ai).

# %%
import os
import sys
import pandas as pd
import numpy as np
import tqdm
import wandb

import torch
from torch.utils.data import Dataset, DataLoader
from torch import nn, optim
import torch.nn.functional as F

from torchtext.vocab import Vectors
from torchtext.data import get_tokenizer

# %%
# mode = 'online'
mode = 'disabled'
wandb.init(project='movie-reviews', entity='dianna-ai', mode=mode)

# %%
# tunable hyperparameters
config = wandb.config
config.batch_size = 64
config.epochs = 10
config.output_dim = 1
config.dropout = .4
config.n_filters = 128
config.filter_sizes = [3, 4, 5]
config.learning_rate = 0.001
config.weight_decay = 0.0003
config.max_samples = 10000  # maximum samples of training set to use

# %%
# select device to run on
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print(f'PyTorch will use {device}')
# Out:
# PyTorch will use cpu

# %%
# path to data files
data_path = 'model/'

# tokenizer for splitting input sentences
tokenizer = get_tokenizer('spacy', 'en_core_web_sm')

# word vectors as generated from data preparation notebook
vocab = Vectors('word_vectors.txt', cache='.')

# %%
# class to hold a dataset
# custom datasets need to implement init, len, and getitem
class MovieReviewDataset(Dataset):
    def __init__(self, filename, tokenizer, vocab, max_samples=None, max_filter_size=None):
        self.tokenizer = tokenizer
        self.vocab = vocab
        self.max_filter_size = max_filter_size

        self.data = pd.read_csv(filename, delimiter='\t')
        if max_samples is not None:
            self.data = self.data[:min(len(self.data), max_samples)]
          
    def __getitem__(self, idx):
        # get sentence and corresponding label
        sentence = self.data.iloc[idx]['sentence']
        label = self.data.iloc[idx]['label']
        # tokenize sentence
        tokens = self.tokenizer(sentence)
        # pad if needed
        if self.max_filter_size is not None:
            tokens = pad(tokens, self.max_filter_size)
        # numericalize
        tokens_numerical = [self.vocab.stoi[token] if token in self.vocab.stoi else self.vocab.stoi['<unk>'] for token in tokens]
        return tokens_numerical, label
    
    def __len__(self):
        return len(self.data)

    
# function to pad to some minimum length
def pad(tokens, max_filter_size, padding_token='<pad>'):
    npad = max(max_filter_size - len(tokens), 0)
    tokens += [padding_token] * npad
    return tokens


# custom collate function to handle variable-size input
def collate(batch, padding_idx):
    # get max sample size: item[0] is the input sentence split into numerical tokens
    tokens = [sample[0] for sample in batch]
    max_size = max(map(len, tokens))
    # create input array with padding such that each element has the same size
    input_data = np.empty((len(batch), max_size), dtype=int)
    for i, item in enumerate(tokens):
        # pad each element and store
        input_data[i] = pad(item, max_size, padding_token=padding_idx)

    # convert to tensors
    input_data = torch.LongTensor(input_data)
    labels = torch.FloatTensor([item[1] for item in batch])
    return [input_data, labels]

# convert collate function to callable that only requires batch as argument
collate_func = lambda batch: collate(batch, vocab.stoi['<pad>'])

# %%
# Load data into PyTorch dataset
# These datasets return the input as numerical values, suited for input to the model

train_data = MovieReviewDataset(os.path.join(data_path, 'train.tsv'), tokenizer, vocab, max_samples=config.max_samples)
val_data = MovieReviewDataset(os.path.join(data_path, 'validation.tsv'), tokenizer, vocab)

# %%
# Create iterators for the data
batch_size = config.batch_size
nworker = min(12, os.cpu_count() - 1)

train_data_iterator = DataLoader(train_data, batch_size=batch_size, shuffle=True, collate_fn=collate_func, num_workers=nworker, pin_memory=True)
val_data_iterator = DataLoader(val_data, batch_size=batch_size, shuffle=True, collate_fn=collate_func, num_workers=nworker, pin_memory=True)

# %%
# create a model
class Model(nn.Module):
    def __init__(self, vocab_size, embedding_size, n_filters, filter_sizes, padding_idx,
                dropout, output_dim):
        super().__init__()
        
        self.embedding = nn.Embedding(vocab_size, embedding_size, padding_idx=padding_idx)
        
        self.conv_layers = nn.ModuleList()
        for filter_size in filter_sizes:
            layer = nn.Conv2d(in_channels=1, out_channels=n_filters, kernel_size=(filter_size, embedding_size))
            self.conv_layers.append(layer)

        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(n_filters * len(filter_sizes), output_dim)
    
    def forward(self, text):
        # shape = [batch size, max nword per sentence]
        embedding = self.embedding(text).unsqueeze(1)
        # shape = [batch_size, 1, nword, embedding dim]
        conved = [F.relu(conv(embedding)).squeeze(3) for conv in self.conv_layers]
        # shape = len(filter_sizes) list of [batch_size, n_filter, nword - filter_size + 1]
        # note: max_pool1d does not work with ONNX when output shape is dynamic
        # therefore switched to adaptive_max_pool1d
        pooled = [F.adaptive_max_pool1d(out, 1).squeeze(2) for out in conved]
        # shape = len(filter_sizes) list of [batch_size, n_filter]
        concat = torch.cat(pooled, dim=1)
        # shape = [batch_size * len(filter_sizes), n_filter]
        dropped = self.dropout(concat)
        return self.fc(dropped)

# %%
# init a model
output_dim = config.output_dim
dropout = config.dropout
n_filters = config.n_filters
filter_sizes = config.filter_sizes

vocab_size, embedding_size = vocab.vectors.size()
padding_idx = vocab.stoi['<pad>']

model = Model(vocab_size, embedding_size, n_filters, filter_sizes, padding_idx, dropout, output_dim)
# copy pre-trained embeddings into model
model.embedding.weight.data.copy_(vocab.vectors)

model = model.to(device)

wandb.watch(model)
# Out:
# []

# %%
# Define training and evaluation functions
# first define optimizer and loss function
optimizer = optim.Adam(model.parameters(), lr=config.learning_rate, weight_decay=config.weight_decay)
loss_func = nn.BCEWithLogitsLoss().to(device)

# function to calculate accuracy
def accuracy(model_output, y_true):
    y_pred = torch.round(torch.sigmoid(model_output))
    return (y_pred == y_true).sum() / len(y_pred)

def train(model, train_data, optimizer, loss_func):
    epoch_loss = 0
    epoch_acc = 0
    model.train()
    
    for batch in tqdm.tqdm(train_data, file=sys.stdout):
        input_data, label = batch
        input_data = input_data.to(device)
        label = label.to(device)
        
        optimizer.zero_grad()
        predictions = model(input_data).squeeze(1)
        
        loss = loss_func(predictions, label)
        acc = accuracy(predictions, label)
        
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
        epoch_acc += acc.item()
        
        wandb.log({'train_loss': loss.item(), 'train_acc': acc.item()})
        
    epoch_loss /= len(train_data)
    epoch_acc /= len(train_data)
    
    wandb.log({'train_epoch_loss': epoch_loss, 'train_epoch_acc': epoch_acc})
                
    return epoch_loss, epoch_acc

def evaluate(model, data, loss_func):
    loss = 0
    acc = 0
    model.eval()
    
    with torch.no_grad():
        for batch in data:
            input_data, label = batch
            input_data = input_data.to(device)
            label = label.to(device)
            predictions = model(input_data).squeeze(1)

            loss += loss_func(predictions, label).item()
            acc += accuracy(predictions, label).item()
            
    loss /= len(data)
    acc /= len(data)
        
    return loss, acc

# %%
# do the training
best_val_loss = np.inf
best_val_acc = np.inf

for epoch in range(config.epochs):
    train_epoch_loss, train_epoch_acc = train(model, train_data_iterator, optimizer, loss_func)
    val_epoch_loss, val_epoch_acc = evaluate(model, val_data_iterator, loss_func)
    # log the validation results to wandb
    wandb.log({'val_epoch_loss': val_epoch_loss, 'val_epoch_acc': val_epoch_acc})
    print(f'train loss: {train_epoch_loss:.2f} | train acc: {train_epoch_acc:.2f}')
    print(f'val   loss: {val_epoch_loss:.2f} | val   acc: {val_epoch_acc:.2f}')
    # store model with best validation loss
    if val_epoch_loss < best_val_loss:
        best_val_loss = val_epoch_loss
        best_val_acc = val_epoch_acc
        # ensure we are in eval mode
        model.eval()
        torch.save(model, 'movie_review_model.pytorch')

print(f"Best validation loss: {best_val_loss:.2f}, accuracy: {best_val_acc:.2f}")
# Out:
# 100%|██████████| 157/157 [00:05<00:00, 26.99it/s]
# train loss: 0.51 | train acc: 0.75
# val   loss: 0.45 | val   acc: 0.79
# 100%|██████████| 157/157 [00:05<00:00, 29.26it/s]
# train loss: 0.34 | train acc: 0.86
# val   loss: 0.42 | val   acc: 0.80
# 100%|██████████| 157/157 [00:05<00:00, 29.21it/s]
# train loss: 0.26 | train acc: 0.90
# val   loss: 0.41 | val   acc: 0.82
# 100%|██████████| 157/157 [00:05<00:00, 29.59it/s]
# train loss: 0.19 | train acc: 0.93
# val   loss: 0.42 | val   acc: 0.80
# 100%|██████████| 157/157 [00:05<00:00, 28.26it/s]
# train loss: 0.15 | train acc: 0.95
# val   loss: 0.47 | val   acc: 0.80
# 100%|██████████| 157/157 [00:05<00:00, 28.55it/s]
# train loss: 0.12 | train acc: 0.97
# val   loss: 0.50 | val   acc: 0.80
# 100%|██████████| 157/157 [00:05<00:00, 29.55it/s]
# train loss: 0.10 | train acc: 0.97
# val   loss: 0.51 | val   acc: 0.80
# 100%|██████████| 157/157 [00:05<00:00, 28.93it/s]
# train loss: 0.08 | train acc: 0.98
# val   loss: 0.57 | val   acc: 0.78
# 100%|██████████| 157/157 [00:05<00:00, 29.80it/s]
# train loss: 0.08 | train acc: 0.98
# val   loss: 0.58 | val   acc: 0.78
# 100%|██████████| 157/157 [00:05<00:00, 29.66it/s]
# train loss: 0.07 | train acc: 0.98
# val   loss: 0.60 | val   acc: 0.78
# Best validation loss: 0.41, accuracy: 0.82

# %%
# load best model from disk
loaded_model = torch.load('movie_review_model.pytorch')
loaded_model = loaded_model.to(device)
loaded_model.eval()

# store as ONNX, needs example input
x = next(iter(train_data_iterator))[0].to(device)
torch.onnx.export(loaded_model, x, 'movie_review_model.onnx', opset_version=11,
                  export_params=True, input_names=['input'], output_names=['output'],
                  dynamic_axes={'input': {0: 'batch_size', 1: 'sentence_length'},
                                'output': {0: 'batch_size'}})

# %%
# class to predict sentiment from a sentence
class Predictor:
    def __init__(self, model, tokenizer, vocab, device, max_filter_size=None):
        self.model = model
        self.tokenizer = tokenizer
        self.vocab = vocab
        self.device = device
        self.max_filter_size = max_filter_size
        self.classes = ['negative', 'positive']
        
        self.model.eval()
        
    def __call__(self, sentence):
        # get numerical tokens
        tokens = tokenizer(sentence)
        # pad if needed
        if self.max_filter_size is not None:
            tokens = pad(tokens, self.max_filter_size)
        # numericalize
        tokens = [self.vocab.stoi[token] if token in self.vocab.stoi else self.vocab.stoi['<unk>'] for token in tokens]
        # move to device and add required batch axis
        tokens = torch.tensor(tokens).unsqueeze(0).to(self.device)
        # feed to model
        pred = torch.sigmoid(model.forward(tokens)).item()
        # get string representation of predicted class
        class_str = self.classes[int(np.round(pred))]
        
        return pred, class_str
    
predict_sentiment = Predictor(loaded_model, tokenizer, vocab, device, max_filter_size=max(config.filter_sizes))

# %%
# print some predictions from the (unlabeled) test set
sentences = pd.read_csv(os.path.join(data_path, 'test.tsv'), delimiter='\t')['sentence']
nmax = 1820
classes = ['negative', 'positive']

for n, sentence in enumerate(sentences):
    if n == nmax:
        break
    output_numerical, predicted_class = predict_sentiment(sentence)
    print(f"\"{sentence}\" - {predicted_class} - {output_numerical:.2f}")
# Out:
# "uneasy mishmash of styles and genres ." - negative - 0.27
# "this film 's relationship to actual tension is the same as what christmas-tree flocking in a spray can is to actual snow : a poor -- if durable -- imitation ." - negative - 0.00
# "by the end of no such thing the audience , like beatrice , has a watchful affection for the monster ." - positive - 0.88
# "director rob marshall went out gunning to make a great one ." - positive - 0.93
# "lathan and diggs have considerable personal charm , and their screen rapport makes the old story seem new ." - positive - 0.99
# "a well-made and often lovely depiction of the mysteries of friendship ." - positive - 1.00
# "none of this violates the letter of behan 's book , but missing is its spirit , its ribald , full-throated humor ." - positive - 0.98
# "although it bangs a very cliched drum at times , this crowd-pleaser 's fresh dialogue , energetic music , and good-natured spunk are often infectious ." - positive - 0.92
# "it is not a mass-market entertainment but an uncompromising attempt by one artist to think about another ." - negative - 0.02
# "this is junk food cinema at its greasiest ." - negative - 0.00
# "it 's also heavy-handed and devotes too much time to bigoted views ." - negative - 0.00
# "it helps that lil bow wow ... tones down his pint-sized gangsta act to play someone who resembles a real kid ." - negative - 0.19
# "watching the film is like reading a times portrait of grief that keeps shifting focus to the journalist who wrote it ." - positive - 1.00
# "moore 's performance impresses almost as much as her work with haynes in 1995 's safe ." - negative - 0.10
# "reinforces the talents of screenwriter charlie kaufman , creator of adaptation and being john malkovich ." - positive - 0.83
# "now trimmed by about 20 minutes , this lavish three-year-old production has enough grandeur and scale to satisfy as grown-up escapism ." - negative - 0.30
# "a journey through memory , a celebration of living , and a sobering rumination on fatality , classism , and ignorance ." - positive - 0.99
# "a remarkable 179-minute meditation on the nature of revolution ." - positive - 1.00
# "waydowntown is by no means a perfect film , but its boasts a huge charm factor and smacks of originality ." - positive - 0.99
# "it 's just incredibly dull ." - negative - 0.27
# "some , like ballistic , arrive stillborn ... looking like the beaten , well-worn video box cover of seven years into the future ." - negative - 0.05
# "a feel-good picture in the best sense of the term ." - positive - 1.00
# "mark me down as a non-believer in werewolf films that are not serious and rely on stupidity as a substitute for humor ." - positive - 0.85
# "good movie ." - positive - 1.00
# "with spy kids 2 : the island of lost dreams writer/director/producer robert rodriguez has cobbled together a film that feels like a sugar high gone awry ." - negative - 0.29
# "starts off with a bang , but then fizzles like a wet stick of dynamite at the very end ." - negative - 0.09
# "the best way to hope for any chance of enjoying this film is by lowering your expectations ." - positive - 1.00
# "while the mystery surrounding the nature of the boat 's malediction remains intriguing enough to sustain mild interest , the picture refuses to offer much accompanying sustenance in the way of characterization , humor or plain old popcorn fun ." - positive - 0.95
# "this is a startling film that gives you a fascinating , albeit depressing view of iranian rural life close to the iraqi border ." - positive - 0.97
# "here 's a british flick gleefully unconcerned with plausibility , yet just as determined to entertain you ." - positive - 0.99
# "most new movies have a bright sheen ." - positive - 0.79
# "so few movies explore religion that it 's disappointing to see one reduce it to an idea that fits in a sampler ." - positive - 0.96
# "nothing more than a mediocre trifle ." - negative - 0.00
# "a model of what films like this should be like ." - positive - 0.98
# "gangs of new york is an unapologetic mess , whose only saving grace is that it ends by blowing just about everything up ." - positive - 0.64
# "doug liman , the director of bourne , directs the traffic well , gets a nice wintry look from his locations , absorbs us with the movie 's spycraft and uses damon 's ability to be focused and sincere ." - positive - 1.00
# "another big , dumb action movie in the vein of xxx , the transporter is riddled with plot holes big enough for its titular hero to drive his sleek black bmw through ." - negative - 0.34
# "it becomes gimmicky instead of compelling ." - positive - 0.93
# "falters when it takes itself too seriously and when it depends too heavily on its otherwise talented cast to clown in situations that are n't funny ." - negative - 0.11
# "verbinski substitutes atmosphere for action , tedium for thrills ." - negative - 0.06
# "it is a kickass , dense sci-fi action thriller hybrid that delivers and then some ." - positive - 1.00
# "a bigger holiday downer than your end-of-year 401 ( k ) statement ." - negative - 0.34
# "as a belated nod to some neglected all-stars , standing in the shadows of motown is cultural history of the best kind : informative , revealing and richly entertaining ." - positive - 1.00
# "sensitive , insightful and beautifully rendered film ." - positive - 1.00
# "no number of fantastic sets , extras , costumes and spectacular locales can disguise the emptiness at the center of the story ." - negative - 0.00
# "not too far below the gloss you can still feel director denis villeneuve 's beating heart and the fondness he has for his characters ." - positive - 0.71
# "for benigni it was n't shakespeare whom he wanted to define his career with but pinocchio ." - negative - 0.17
# "how did it ever get made ?" - negative - 0.06
# "it would n't be my preferred way of spending 100 minutes or $ 7.00 ." - negative - 0.02
# "the furious coherence that ( deniro ) brings to this part only underscores the fuzzy sentimentality of the movie itself , which feels , as it plods toward the end , less like a movie than like the filmed reading of a script in need of polishing ." - negative - 0.31
# "barely goes beyond comic book status ." - positive - 0.99
# "elling , portrayed with quiet fastidiousness by per christian ellefsen , is a truly singular character , one whose frailties are only slightly magnified versions of the ones that vex nearly everyone ." - positive - 0.99
# "for all its highfalutin title and corkscrew narrative , the movie turns out to be not much more than a shaggy human tale ." - negative - 0.25
# "watching trouble every day , at least if you do n't know what 's coming , is like biting into what looks like a juicy , delicious plum on a hot summer day and coming away with your mouth full of rotten pulp and living worms ." - negative - 0.15
# "a clever blend of fact and fiction ." - positive - 0.84
# "it delivers some chills and sustained unease , but flounders in its quest for deeper meaning ." - positive - 0.91
# "could the country bears really be as bad as its trailers ?" - negative - 0.00
# "there are weird resonances between actor and role here , and they 're not exactly flattering ." - negative - 0.05
# "not only does the movie fail to make us part of its reality , it fails the most basic relevancy test as well ." - negative - 0.00
# "and if the hours wins ` best picture ' i just might ." - positive - 1.00
# "it is so refreshing to see robin williams turn 180 degrees from the string of insultingly innocuous and sappy fiascoes he 's been making for the last several years ." - positive - 1.00
# "i did n't laugh at the ongoing efforts of cube , and his skinny buddy mike epps , to make like laurel and hardy 'n the hood ." - negative - 0.14
# "with danilo donati 's witty designs and dante spinotti 's luscious cinematography , this might have made a decent children 's movie -- if only benigni had n't insisted on casting himself in the title role ." - positive - 0.93
# "thurman and lewis are hilarious throughout ." - positive - 1.00
# "tender yet lacerating and darkly funny fable ." - positive - 1.00
# "jacquot 's tosca is a treat ." - positive - 0.93
# "interacting eyeball-to-eyeball and toe-to-toe , hopkins and norton are a winning combination -- but fiennes steals ` red dragon ' right from under their noses ." - positive - 0.82
# "the film 's center will not hold ." - negative - 0.08
# "aspires for the piquant but only really achieves a sort of ridiculous sourness ." - negative - 0.16
# "unlike his directorial efforts , la femme nikita and the professional , the transporter lacks besson 's perspective as a storyteller ." - negative - 0.02
# "` abandon all hope , ye who enter here ' ... you should definitely let dante 's gloomy words be your guide ." - negative - 0.04
# "a very witty take on change , risk and romance , and the film uses humor to make its points about acceptance and growth ." - positive - 1.00
# "hu and liu offer natural , matter-of-fact performances that glint with sorrow , longing and love ." - positive - 0.99
# "ford deserves to be remembered at oscar time for crafting this wonderful portrait of a conflicted soldier ." - positive - 1.00
# "a mawkish , implausible platonic romance that makes chaplin 's city lights seem dispassionate by comparison ." - positive - 0.76
# "do we really need a 77-minute film to tell us exactly why a romantic relationship between a 15-year-old boy and a 40-year-old woman does n't work ?" - negative - 0.20
# "instead , we just get messy anger , a movie as personal therapy ." - negative - 0.38
# "once again , director jackson strikes a rewarding balance between emotion on the human scale and action/effects on the spectacular scale ." - positive - 0.98
# "flotsam in the sea of moviemaking , not big enough for us to worry about it causing significant harm and not smelly enough to bother despising ." - negative - 0.29
# "thoughtful , provocative and entertaining ." - positive - 1.00
# "it 's disappointing when filmmakers throw a few big-name actors and cameos at a hokey script ." - negative - 0.02
# "an absorbing , slice-of-depression life that touches nerves and rings true ." - positive - 1.00
# "u.s. audiences may find ( attal and gainsbourg 's ) unfamiliar personas give the film an intimate and quaint reality that is a little closer to human nature than what hollywood typically concocts ." - positive - 0.96
# "everywhere the camera looks there is something worth seeing ." - positive - 0.95
# "but if it is indeed a duty of art to reflect life , than leigh has created a masterful piece of artistry right here ." - positive - 1.00
# "biggie and tupac is so single-mindedly daring , it puts far more polished documentaries to shame ." - positive - 0.98
# "... the last time i saw a theater full of people constantly checking their watches was during my sats ." - positive - 0.73
# "will probably stay in the shadow of its two older , more accessible qatsi siblings ." - negative - 0.18
# "characters wander into predictably treacherous situations even though they should know better ." - positive - 0.92
# "i 'm not suggesting that you actually see it , unless you 're the kind of person who has seen every wim wenders film of the '70s ." - positive - 0.96
# "gloriously goofy ( and gory ) midnight movie stuff ." - negative - 0.07
# "an inspiring and heart-affecting film about the desperate attempts of vietnamese refugees living in u.s. relocation camps to keep their hopes alive in 1975 ." - positive - 0.94
# "big fat liar is just futile silliness looking to tap into the kiddie sensibilities ." - negative - 0.03
# "the movie is full of fine performances , led by josef bierbichler as brecht and monica bleibtreu as helene weigel , his wife ." - positive - 0.99
# "barney has created a tour de force that is weird , wacky and wonderful ." - positive - 1.00
# "a frisky and fresh romantic comedy exporing sexual politics and the challenges of friendships between women ." - positive - 0.99
# "the comic performances are all spot on , especially lee ross 's turn as ken ." - positive - 1.00
# "the film hinges on its performances , and both leads are up to the task ." - positive - 0.84
# "accuracy and realism are terrific , but if your film becomes boring , and your dialogue is n't smart , then you need to use more poetic license ." - positive - 0.79
# "it 's often faintly amusing , but the problems of the characters never become important to us , and the story never takes hold ." - negative - 0.19
# "the thrill is ( long ) gone ." - positive - 0.82
# "uncertain in tone ... a garbled exercise in sexual politics , a junior varsity short cuts by way of very bad things ." - negative - 0.01
# "a hideous , confusing spectacle , one that may well put the nail in the coffin of any future rice adaptations ." - positive - 0.92
# "there 's a vastness implied in metropolis that is just breathtaking ." - negative - 0.28
# "a splendid entertainment , young in spirit but accomplished in all aspects with the fullness of spirit and sense of ease that comes only with experience ." - positive - 1.00
# "the story ... is moldy and obvious ." - positive - 0.75
# "it 's a worthwhile tutorial in quantum physics and slash-dash" - positive - 0.93
# "for all its failed connections , divine secrets of the ya-ya sisterhood is nurturing , in a gauzy , dithering way ." - positive - 0.94
# "george , hire a real director and good writers for the next installment , please ." - positive - 0.99
# "what was subtle and mystifying in the novella is now broad and farcical ." - positive - 0.67
# "it 's best to avoid imprisonment with the dull , nerdy folks that inhabit cherish ." - negative - 0.13
# "woo 's fights have a distinct flair ." - positive - 0.75
# "he has not learned that storytelling is what the movies are about ." - positive - 0.77
# "if you liked the 1982 film then , you 'll still like it now ." - positive - 1.00
# "despite some gulps the film is a fuzzy huggy ." - positive - 0.98
# "the film is painfully authentic , and the performances of the young players are utterly convincing ." - positive - 1.00
# "there are just enough twists in the tale to make it far more satisfying than almost any horror film in recent memory ." - positive - 0.91
# "this is n't just the cliffsnotes version of nicholas nickleby , it 's the cliffsnotes with pages missing ." - positive - 0.51
# "`` an entire film about researchers quietly reading dusty old letters . ''" - negative - 0.04
# "an epic of grandeur and scale that 's been decades gone from the popcorn pushing sound stages of hollywood ." - positive - 1.00
# "there 's a disreputable air about the whole thing , and that 's what makes it irresistible ." - positive - 0.85
# "it virtually defines a comedy that 's strongly mediocre , with funny bits surfacing every once in a while ." - negative - 0.17
# "although very much like the first movie based on j.k. rowling 's phenomenal fantasy best sellers , this second go-round possesses a quite pleasing , headlong thrust and a likably delinquent attitude ." - positive - 0.94
# "theology aside , why put someone who ultimately does n't learn at the center of a kids ' story ?" - negative - 0.02
# "a savvy exploration of paranoia and insecurity in america 's culture of fear ." - positive - 0.99
# "benefits from a strong performance from zhao , but it 's dong jie 's face you remember at the end ." - positive - 1.00
# "elling really is about a couple of crazy guys , and it 's therapeutic to laugh along with them ." - positive - 0.93
# "much-anticipated and ultimately lackluster movie ." - negative - 0.26
# "plays as hollow catharsis , with lots of tears but very little in the way of insights ." - negative - 0.11
# "a film that takes you inside the rhythms of its subject : you experience it as you watch ." - positive - 1.00
# "... mesmerizing , an eye-opening tour of modern beijing culture in a journey of rebellion , retreat into oblivion and return ." - positive - 1.00
# "strong setup and ambitious goals fade as the film descends into unsophisticated scare tactics and b-film thuggery ." - negative - 0.02
# "on the surface , it 's a lovers-on-the-run crime flick , but it has a lot in common with piesiewicz 's and kieslowski 's earlier work , films like the double life of veronique ." - positive - 0.98
# "the visuals alone make metropolis worth seeing ." - positive - 0.99
# "flounders due to the general sense that no two people working on the production had exactly the same thing in mind ." - negative - 0.11
# "you could nap for an hour and not miss a thing ." - negative - 0.07
# "worth the effort to watch ." - positive - 1.00
# "one of the best of the year ." - positive - 1.00
# "i loved it !" - positive - 0.91
# "occasionally funny , always very colorful and enjoyably overblown in the traditional almodóvar style ." - positive - 0.78
# "an intelligent , earnest , intimate film that drops the ball only when it pauses for blunt exposition to make sure you 're getting its metaphysical point ." - positive - 1.00
# "an amusing , breezily apolitical documentary about life on the campaign trail ." - positive - 1.00
# "however , it lacks grandeur and that epic quality often associated with stevenson 's tale as well as with earlier disney efforts ." - negative - 0.42
# "often hilarious , well-shot and , importantly , entertaining , hell house is a fascinating document of an event that has to be seen to be believed ." - positive - 1.00
# "witty , touching and well paced ." - positive - 1.00
# "men in black ii has sequel-itis something fierce ." - negative - 0.47
# "sometimes , nothing satisfies like old-fashioned swashbuckling ." - negative - 0.26
# "it settles for being merely grim ." - positive - 0.93
# "good for a few unintentional laughs , `` extreme ops '' was obviously made for the `` xxx '' crowd , people who enjoy mindless action without the benefit of decent acting , writing , and direction ." - negative - 0.05
# "places a slightly believable love triangle in a difficult-to-swallow setting , and then disappointingly moves the story into the realm of an improbable thriller ." - positive - 0.93
# "a mostly intelligent , engrossing and psychologically resonant suspenser ." - positive - 1.00
# "at first , the sight of a blind man directing a film is hilarious , but as the film goes on , the joke wears thin ." - positive - 0.91
# "as an actor , the rock is aptly named ." - positive - 0.89
# "plays less like a coming-of-age romance than an infomercial ." - negative - 0.37
# "with its hints of a greater intelligence lurking somewhere , the ring makes its stupidity more than obvious ." - negative - 0.13
# "this insightful , oscar-nominated documentary , in which children on both sides of the ever-escalating conflict have their say away from watchful parental eyes , gives peace yet another chance ." - positive - 0.99
# "all but the most persnickety preteens should enjoy this nonthreatening but thrilling adventure ." - positive - 0.94
# "i admired this work a lot ." - negative - 0.42
# "this concoction , so bizarre to the adult mind , is actually a charming triumph where its intended under-12 audience is concerned ." - positive - 0.96
# "( a ) rare , beautiful film ." - positive - 1.00
# "the pianist is a fine valedictory work for polanski , made richer by his own experiences , making his other movies somehow richer in the bargain ." - positive - 0.91
# "if you 're like me , a sucker for a good old fashion romance and someone who shamelessly loves to eat , then mostly martha offers all the perfect ingredients to more than satisfy your appetite ." - positive - 0.62
# "the screenplay sabotages the movie 's strengths at almost every juncture ." - positive - 0.79
# "not even the hanson brothers can save it" - negative - 0.01
# "then lower them a bit more ." - negative - 0.23
# "the truth is that the truth about charlie gets increasingly tiresome ." - positive - 0.99
# "there are a few laughs and clever sight gags scattered about , but not enough to make this anything more than another big-budget bust ." - negative - 0.01
# "a deviant topical comedy which is funny from start to finish ." - positive - 0.96
# "an elegant , exquisitely modulated psychological thriller ." - positive - 1.00
# "brilliant ! '" - positive - 1.00
# "working from elliott 's memoir , rohmer fashions the sort of delicate , articulate character - and - relationship study he 's favored for decades ." - positive - 0.99
# "a picture that extols the virtues of comradeship and community in a spunky , spirited fashion ." - positive - 0.99
# "if you think that jennifer lopez has shown poor judgment in planning to marry ben affleck , wait till you see maid in manhattan ." - negative - 0.01
# "has little on its mind aside from scoring points with drag gags ." - negative - 0.00
# "apallingly absurd ... the chemistry or lack thereof between newton and wahlberg could turn an imax theater into a 9 '' black and white portable tv ." - negative - 0.18
# "maybe it 's the star power of the cast or the redundant messages , but something aboul `` full frontal '' seems , well , contrived ." - positive - 0.94
# "a budget affair that exposes the generally sad existence of the bedouins while providing a precious twinkle of insight into their lives ." - positive - 0.61
# "it does n't help that the director and cinematographer stephen kazmierski shoot on grungy video , giving the whole thing a dirty , tasteless feel ." - negative - 0.05
# "this cheery , down-to-earth film is warm with the cozy feeling of relaxing around old friends ." - positive - 1.00
# "it 's an example of sophisticated , challenging filmmaking that stands , despite its noticeable lack of emotional heft , in welcome contrast to the indulgent dead-end experimentation of the director 's previous full frontal ." - negative - 0.08
# "merchant effectively translates naipaul 's lively mix of characters from the page to screen ." - positive - 1.00
# "the angst-ridden , affluent slacker characters are more grating than engaging ." - negative - 0.02
# "it 's the cinematic equivalent of a good page-turner , and even if it 's nonsense , its claws dig surprisingly deep ." - positive - 0.67
# "... a cute and sometimes side-splittingly funny blend of legally blonde and drop dead gorgeous , starring piper perabo in what could be her breakthrough role ." - positive - 0.96
# "made by jackasses for jackasses ." - positive - 0.65
# "emerges as something rare , an issue movie that 's so honest and keenly observed that it does n't feel like one ." - positive - 0.88
# "a recent favorite at sundance , this white-trash satire will inspire the affection of even those unlucky people who never owned a cassette of def leppard 's pyromania ." - positive - 0.70
# "an involving true story of a chinese actor who takes up drugs and winds up in an institution -- acted mostly by the actual people involved ." - positive - 0.95
# "the movie bounces all over the map ." - negative - 0.03
# "it has the courage to wonder about big questions with sincerity and devotion ." - positive - 1.00
# "watching scarlet diva , one is poised for titillation , raw insight or both ." - positive - 0.78
# "apparently kissing leads to suicide attempts and tragic deaths ." - negative - 0.02
# "only an epic documentary could get it all down , and spike lee 's jim brown : all american at long last gives its subject a movie worthy of his talents ." - positive - 0.97
# "do n't let your festive spirit go this far ." - positive - 0.96
# "if melville is creatively a great whale , this film is canned tuna ." - positive - 0.99
# "the whole damn thing is ripe for the jerry springer crowd ." - negative - 0.35
# "occasionally melodramatic , it 's also extremely effective ." - negative - 0.27
# "director kapur is a filmmaker with a real flair for epic landscapes and adventure , and this is a better film than his earlier english-language movie , the overpraised elizabeth ." - positive - 0.99
# "when it 's all wet , blue crush is highly enjoyable ." - positive - 0.99
# "... ( like ) channel surfing between the discovery channel and a late-night made-for-cable action movie ." - negative - 0.20
# "the problem with concept films is that if the concept is a poor one , there 's no saving the movie ." - negative - 0.00
# "new best friend should n't have gone straight to video ; it should have gone straight to a mystery science theater 3000 video ." - negative - 0.31
# "even the unwatchable soapdish is more original ." - positive - 0.53
# "an overblown clunker full of bad jokes , howling cliches and by-the-numbers action sequences ." - negative - 0.00
# "smart science fiction for grown-ups , with only a few false steps along the way ." - negative - 0.41
# "the use of cgi and digital ink-and-paint make the thing look really slick ." - positive - 0.91
# "a historical epic with the courage of its convictions about both scope and detail ." - positive - 1.00
# "a resonant tale of racism , revenge and retribution ." - positive - 1.00
# "( sen 's ) soap opera-ish approach undermines his good intentions ." - negative - 0.07
# "( director ) byler may yet have a great movie in him , but charlotte sometimes is only half of one ." - positive - 0.70
# "the movie has lots of dancing and fabulous music ." - positive - 0.96
# "a highly intriguing thriller , coupled with some ingenious plot devices and some lavishly built settings . ." - positive - 1.00
# "well worth the time ." - positive - 1.00
# "overall , the film misses the brilliance of jelinek 's novel by some way ." - positive - 0.77
# "( davis ) has a bright , chipper style that keeps things moving , while never quite managing to connect her wish-fulfilling characters to the human race ." - positive - 1.00
# "the movie is one of the best examples of artful large format filmmaking you are likely to see anytime soon ." - positive - 1.00
# "hayek is stunning as frida and ... a star-making project ." - positive - 0.91
# "a painfully leaden film destined for pre-dawn cable television slots ." - negative - 0.02
# "everything that has to do with yvan and charlotte , and everything that has to do with yvan 's rambunctious , jewish sister and her non-jew husband , feels funny and true ." - positive - 0.67
# "when the first few villians are introduced as `` spider '' and `` snake '' you know you 're in for a real winner , creativity at its peak ." - positive - 0.98
# "not every animated film from disney will become a classic , but forgive me if i 've come to expect more from this studio than some 79-minute after-school `` cartoon '' ." - positive - 0.74
# "while this film is not in the least surprising , it is still ultimately very satisfying ." - positive - 0.53
# "a hip ride into hyper-time , clockstoppers is a lively and enjoyable adventure for all ages at any time ." - positive - 1.00
# "john leguizamo may be a dramatic actor -- just not in this movie ." - negative - 0.01
# "like mike does n't win any points for originality ." - negative - 0.01
# "some movies are like a tasty hors-d'oeuvre ; this one is a feast ." - positive - 0.97
# "one of those movies where you walk out of the theater not feeling cheated exactly , but feeling pandered to , which , in the end , might be all the more infuriating ." - positive - 0.64
# "fuller would surely have called this gutsy and at times exhilarating movie a great yarn ." - positive - 0.99
# "it 's a brave attempt to tap into the heartbeat of the world , a salute to the universal language of rhythm and a zippy sampling of sounds ." - positive - 0.97
# "an incredibly low-rent danish film , it brings a group of people together in a sweet and charming way , if a little convenient" - positive - 0.98
# "it 's push-the-limits teen comedy , the type written by people who ca n't come up with legitimate funny , and it 's used so extensively that good bits are hopelessly overshadowed ." - positive - 0.88
# "in a normal screen process , these bromides would be barely enough to sustain an interstitial program on the discovery channel ." - negative - 0.10
# "its underlying mythology is a hodgepodge of inconsistencies that pose the question : since when did dumb entertainment have to be this dumb ?" - negative - 0.21
# "their film falters , however , in its adherence to the disney philosophy of required poignancy , a salute that i 'd hoped the movie would avoid ." - positive - 0.51
# "an awkward and indigestible movie ." - negative - 0.04
# "friday after next has the same problem that next friday did -- it 's called where 's chris tucker when you need him ?" - negative - 0.01
# "another rent installment for the ian fleming estate ." - negative - 0.39
# "i can only imagine one thing worse than kevin spacey trying on an irish accent , and that 's sultry linda fiorentino doing the same thing ." - negative - 0.00
# "afraid to pitch into farce , yet only half-hearted in its spy mechanics , all the queen 's men is finally just one long drag ." - positive - 0.75
# "who knows what exactly godard is on about in this film , but his words and images do n't have to add up to mesmerize you ." - positive - 0.95
# "herzog is obviously looking for a moral to his fable , but the notion that a strong , unified showing among germany and eastern european jews might have changed 20th-century history is undermined by ahola 's inadequate performance ." - positive - 0.60
# "the story and characters are nowhere near gripping enough ." - negative - 0.07
# "( a ) superbly controlled , passionate adaptation of graham greene 's 1955 novel ." - positive - 1.00
# "though the violence is far less sadistic than usual , the film is typical miike : fast , furious and full of off-the-cuff imaginative flourishes ." - negative - 0.11
# "its scenes and sensibility are all more than familiar , but it exudes a kind of nostalgic spy-movie charm and , at the same time , is so fresh and free of the usual thriller nonsense that it all seems to be happening for the first time ." - positive - 0.92
# "like so many other allegedly scary movies , it gets so tangled up in the twist that it chokes the energy right out of the very audience it seeks to frighten ." - negative - 0.48
# "a bravura exercise in emptiness ." - negative - 0.05
# "has a plot full of twists upon knots ... and a nonstop parade of mock-tarantino scuzbag types that starts out clever but veers into overkill ." - positive - 0.84
# "too clunky and too busy ribbing itself to be truly entertaining ." - negative - 0.00
# "a marvellous journey from childhood idealism to adolescent self-absorption ." - positive - 0.78
# "how on earth , or anywhere else , did director ron underwood manage to blow $ 100 million on this ?" - positive - 0.80
# "a baffling misfire , and possibly the weakest movie ( woody allen ) has made in the last twenty years ." - negative - 0.00
# "hawke draws out the best from his large cast in beautifully articulated portrayals that are subtle and so expressive they can sustain the poetic flights in burdette 's dialogue ." - positive - 1.00
# "the cartoon that is n't really good enough to be on afternoon tv is now a movie that is n't really good enough to be in theaters ." - negative - 0.36
# "a distant , even sterile , yet compulsively watchable look at the sordid life of hogan 's heroes star bob crane ." - positive - 0.98
# "you 've seen them a million times ." - positive - 0.98
# "the best you can say about it is it 's so uninspired , it barely gives one pause when considering some of the other dreck out there right now ." - positive - 0.53
# "arguably the year 's silliest and most incoherent movie ." - positive - 0.58
# "offensive in the way it exploits the hot-button issue of domestic abuse for cheap thrills and disgusting in the manner it repeatedly puts a small child in jeopardy , treating her as little more than a prop to be cruelly tormented ." - negative - 0.02
# "one minute , you think you 're watching a serious actioner ; the next , it 's as though clips from the pink panther strikes again and/or sailor moon have been spliced in ." - negative - 0.37
# "scene-by-scene , things happen , but you 'd be hard-pressed to say what or why ." - negative - 0.04
# "a lousy movie that 's not merely unwatchable , but also unlistenable ." - negative - 0.01
# "an ultra-low-budget indie debut that smacks more of good intentions than talent ." - positive - 0.76
# "if you pitch your expectations at an all time low , you could do worse than this oddly cheerful -- but not particularly funny -- body-switching farce ." - negative - 0.02
# "will grab your children by the imagination and amaze them and amuse them ." - positive - 0.88
# "the film starts out as competent but unremarkable ... and gradually grows into something of considerable power ." - positive - 1.00
# "it would be hard to think of a recent movie that has worked this hard to achieve this little fun ." - negative - 0.44
# "something the true film buff will enjoy ." - positive - 0.99
# "without resorting to hyperbole , i can state that kissing jessica stein may be the best same-sex romance i have seen ." - positive - 0.98
# "the cast is so low-wattage that none of the characters comes off as big ... and the setting remains indistinct ." - negative - 0.00
# "this is a throwaway , junk-food movie whose rap soundtrack was better tended to than the film itself ." - negative - 0.01
# "a teasing drama whose relentless good-deed/bad-deed reversals are just interesting enough to make a sinner like me pray for an even more interesting , less symmetrical , less obviously cross-shaped creation ." - negative - 0.15
# "the movie exists for its soccer action and its fine acting ." - negative - 0.12
# "tim allen is great in his role but never hogs the scenes from his fellow cast , as there are plenty of laughs and good lines for everyone in this comedy ." - positive - 0.93
# "a bowel-curdling , heart-stopping recipe for terror ." - positive - 0.87
# "nicely serves as an examination of a society in transition ." - positive - 0.97
# "if you 're looking for comedy to be served up , better look elsewhere ." - positive - 0.98
# "after that , it just gets stupid and maudlin ." - negative - 0.00
# "the humor is hinged on the belief that knees in the crotch , elbows in the face and spit in the eye are inherently funny ." - positive - 0.83
# "engagingly captures the maddening and magnetic ebb and flow of friendship ." - positive - 1.00
# "sam jones became a very lucky filmmaker the day wilco got dropped from their record label , proving that one man 's ruin may be another 's fortune ." - positive - 0.79
# "the film benefits greatly from a less manic tone than its predecessor , as cho appears to have settled comfortably into her skin ." - positive - 0.86
# "the charms of willful eccentricity , at least as evidenced by this latest cinematic essay , are beginning to wear a bit thin ." - negative - 0.09
# "it feels like a community theater production of a great broadway play : even at its best , it will never hold a candle to the original ." - positive - 0.96
# "a tough go , but leigh 's depth and rigor , and his skill at inspiring accomplished portrayals that are all the more impressive for their lack of showiness , offsets to a notable degree the film 's often-mined and despairing milieu ." - positive - 0.99
# "an irresistible combination of a rousing good story set on a truly grand scale ." - positive - 0.99
# "frida 's artistic brilliance is undeniable -- it 's among the most breathtakingly designed films i 've ever seen ." - positive - 1.00
# "the movie stays afloat thanks to its hallucinatory production design ." - positive - 1.00
# "provide ( s ) nail-biting suspense and credible characters without relying on technology-of-the-moment technique or pretentious dialogue ." - negative - 0.33
# "smith 's approach is never to tease , except gently and in that way that makes us consider our own eccentricities and how they are expressed through our homes ." - positive - 0.99
# "a modest and messy metaphysical thriller offering more questions than answers ." - positive - 1.00
# "a refreshing korean film about five female high school friends who face an uphill battle when they try to take their relationships into deeper waters ." - positive - 1.00
# "now it 's a bad , embarrassing movie ." - negative - 0.01
# "celebrated at sundance , this slight comedy of manners has winning performances and a glossy , glib charm that 's hard to beat ." - positive - 0.96
# "... the sum of the parts equals largely a confused mediocrity ." - negative - 0.14
# "it 's solid and affecting and exactly as thought-provoking as it should be ." - positive - 1.00
# "enough trivializes an important crisis , reduces it to an almost comic embarrassment ." - negative - 0.35
# "between bedroom scenes , viewers may find themselves wishing they could roll over and take a nap ." - negative - 0.22
# "genuinely touching because it 's realistic about all kinds of love ." - positive - 1.00
# "a lighthearted , feel-good film that embraces the time-honored truth that the most powerful thing in life is love ." - positive - 1.00
# "( two ) fairly dull -- contrasting and interlocking stories about miserable scandinavian settlers in 18th-century canada , and yuppie sailboaters in the here and now ." - negative - 0.01
# "a quietly reflective and melancholy new zealand film about an eventful summer in a 13-year-old girl 's life ." - positive - 0.98
# "reign of fire may be little more than another platter of reheated aliens , but it 's still pretty tasty ." - negative - 0.01
# "provides an intriguing window into the imagination and hermetic analysis of todd solondz ." - positive - 1.00
# "dull , if not devoid of wit , this shaggy dog longs to frisk through the back alleys of history , but scarcely manages more than a modest , snoozy charm ." - negative - 0.02
# "the movie 's ripe , enrapturing beauty will tempt those willing to probe its inscrutable mysteries ." - positive - 1.00
# "a predictable and stereotypical little b-movie ." - negative - 0.00
# "it 's astonishing ." - positive - 0.83
# "this is such a high-energy movie where the drumming and the marching are so excellent , who cares if the story 's a little weak ." - positive - 0.95
# "claude miller airs out a tight plot with an easy pace and a focus on character drama over crime-film complications ." - positive - 0.60
# "myers never knows when to let a gag die ; thus , we 're subjected to one mind-numbingly lengthy riff on poo and pee jokes after another ." - negative - 0.01
# "if you can get past the fantastical aspects and harsh realities of `` the isle '' you 'll get a sock-you-in-the-eye flick that is a visual tour-de-force and a story that is unlike any you will likely see anywhere else ." - positive - 0.63
# "enormously likable , partly because it is aware of its own grasp of the absurd ." - positive - 0.96
# "i cry for i spy -- or i would if this latest and laziest imaginable of all vintage-tv spinoffs were capable of engendering an emotional response of any kind ." - negative - 0.01
# "a mostly tired retread of several other mob tales ." - negative - 0.00
# "but it pays a price for its intricate intellectual gamesmanship ." - positive - 0.99
# "the stunning , dreamlike visuals will impress even those viewers who have little patience for euro-film pretension ." - positive - 0.93
# "a movie that will touch the hearts of both children and adults , as well as bring audiences to the edge of their seats ." - positive - 1.00
# "a film that is a portrait of grace in an imperfect world ." - positive - 1.00
# "i do n't have an i am sam clue ." - negative - 0.00
# "the piano teacher is the sort of movie that discourages american audiences from ever wanting to see another foreign film ." - positive - 0.53
# "the film equivalent of a toy chest whose contents get scattered over the course of 80 minutes ." - negative - 0.00
# "suggests puns about ingredients and soup and somebody being off their noodle , but let 's just say the ingredients do n't quite add up to a meal ." - negative - 0.04
# "the film is really not so much bad as bland ." - negative - 0.00
# "cho 's fearless in picking apart human foibles , not afraid to lay her life bare in front of an audience ." - negative - 0.18
# "noyce 's film is contemplative and mournfully reflective ." - positive - 0.98
# "i doubt anyone will remember the picture by the time christmas really rolls around , but maybe it 'll be on video by then ." - positive - 0.75
# "merely as a technical , logistical feat , russian ark marks a cinematic milestone ." - positive - 0.99
# "more than makes up for its mawkish posing by offering rousing spates of genuine feeling ." - positive - 0.98
# "a real story about real people living their lives concerned about the future of an elderly , mentally handicapped family member ." - positive - 0.97
# "painful to watch , but viewers willing to take a chance will be rewarded with two of the year 's most accomplished and riveting film performances ." - positive - 1.00
# "the laser-projected paintings provide a spell-casting beauty , while russell and dreyfus are a romantic pairing of hearts , preciously exposed as history corners them ." - positive - 0.99
# "`` men in black ii , '' has all the earmarks of a sequel ." - negative - 0.23
# "any film featuring young children threatened by a terrorist bomb can no longer pass as mere entertainment ." - positive - 0.69
# "let 's cut to the consumer-advice bottom line : stay home ." - negative - 0.00
# "the long-range appeal of `` minority report '' should transcend any awards it bags ." - negative - 0.46
# "... perhaps the heaviest , most joyless movie ever made about giant dragons taking over the world ." - positive - 0.54
# "workmanlike , maybe , but still a film with all the elements that made the other three great , scary times at the movies ." - positive - 0.99
# "there are moments in this account of the life of artist frida kahlo that are among cinema 's finest this year ." - positive - 0.99
# "does n't amount to much of anything ." - negative - 0.01
# "while the isle is both preposterous and thoroughly misogynistic , its vistas are incredibly beautiful to look at ." - positive - 0.99
# "an instant candidate for worst movie of the year ." - negative - 0.00
# "so what is the point ?" - negative - 0.23
# "longley has constructed a remarkably coherent , horrifically vivid snapshot of those turbulent days ." - positive - 1.00
# "the only element of suspense is whether the movie will change titles or distributors again before the closing credits roll ." - positive - 0.59
# "it may be an easy swipe to take , but this barbershop just does n't make the cut ." - positive - 0.55
# "yeah , these flicks are just that damn good ." - positive - 0.99
# "but what spectacular sizzle it is !" - positive - 0.79
# "an enjoyably half-wit remake of the venerable italian comedy big deal on madonna street ." - positive - 0.65
# "ritchie 's treatment of the class reversal is majorly ham-fisted , from the repetitive manifestos that keep getting thrown in people 's faces to the fact amber is such a joke ." - negative - 0.01
# "earns its laughs from stock redneck ` types ' and from the many , many moments when we recognize even without the elizabethan prose , the play behind the thing ." - positive - 0.80
# "if myers decides to make another austin powers movie , maybe he should just stick with austin and dr evil ." - negative - 0.06
# "it takes this never-ending confusion and hatred , puts a human face on it , evokes shame among all who are party to it and even promotes understanding ." - positive - 0.53
# "a monster combat thriller as impersonal in its relentlessness as the videogame series that inspired it ." - negative - 0.01
# "a sensitive and expertly acted crowd-pleaser that is n't above a little broad comedy and a few unabashedly sentimental tears ." - positive - 0.67
# "kinnear gives a tremendous performance ." - positive - 1.00
# "if you love motown music , you 'll love this documentary ." - positive - 1.00
# "as blunt as it is in depicting child abuse , el bola is a movie steeped in an ambiguity that lends its conflicts a symbolic resonance ." - negative - 0.26
# "the writers , director wally wolodarsky , and all the actors should start their own coeducational fraternity : kappa rho alpha phi ." - negative - 0.29
# "has the feel of an unedited personal journal ." - positive - 0.90
# "the voices are fine as well ." - positive - 0.99
# "this is carion 's debut feature but his script and direction hums with a confidence that many spend entire careers trying to reach ." - positive - 0.56
# "has it ever been possible to say that williams has truly inhabited a character ?" - positive - 0.71
# "what you get with empire is a movie you 've seen many times before , repackaged as new material because there is a latino in the lead ." - positive - 0.73
# "greengrass has delivered an undoubted stylistic tour-de-force , and has managed elements such as sound and cinematography with skill" - positive - 0.85
# "but as a movie , it 's a humorless , disjointed mess ." - negative - 0.00
# "there are times when a rumor of angels plays like an extended episode of touched by an angel -- a little too much dancing , a few too many weeping scenes -- but i liked its heart and its spirit ." - negative - 0.01
# "usually when i get this much syrup , i like pancakes to go with it ." - positive - 0.66
# "if you sometimes like to go to the movies to have fun , wasabi is a good place to start ." - positive - 1.00
# "philip k. dick must be turning in his grave , along with my stomach ." - positive - 0.84
# "demands too much of most viewers ." - negative - 0.07
# "a benign but forgettable sci-fi diversion ." - negative - 0.00
# "showtime is closer to slowtime ." - positive - 0.94
# "a charming yet poignant tale of the irrevocable ties that bind ." - positive - 1.00
# "a boring , formulaic mix of serial killers and stalk 'n' slash ." - negative - 0.00
# "any movie this boring should be required to have ushers in the theater that hand you a cup of coffee every few minutes ." - negative - 0.13
# "at times funny and at other times candidly revealing , it 's an intriguing look at two performers who put themselves out there because they love what they do ." - positive - 1.00
# "ostensibly celebrates middle-aged girl power , even as it presents friendship between women as pathetic , dysfunctional and destructive ." - positive - 0.84
# "preposterous and tedious , sonny is spiked with unintentional laughter that , unfortunately , occurs too infrequently to make the film even a guilty pleasure ." - negative - 0.00
# "the inherent strength of the material as well as the integrity of the filmmakers gives this coming-of-age story restraint as well as warmth ." - positive - 0.99
# "i just did n't care as much for the story ." - negative - 0.00
# "it 's an awfully derivative story ." - positive - 0.82
# "the film makes a tragic error by going on for too long , trying to mirror every subsequent event in chinese history : war , revolution , communism , etc. ." - negative - 0.02
# "4 friends , 2 couples , 2000 miles , and all the pabst blue ribbon beer they can drink - it 's the ultimate redneck road-trip ." - negative - 0.30
# "nervy and sensitive , it taps into genuine artistic befuddlement , and at the same time presents a scathing indictment of what drives hollywood ." - positive - 0.97
# "the low-budget full frontal was one of the year 's murkiest , intentionally obscure and self-indulgent pictures , and solaris is its big-budget brother ." - negative - 0.04
# "novak manages to capture a cruelly hilarious vein of black comedy in the situation with his cast of non-actors and a gritty , no-budget approach ." - positive - 1.00
# "chaotic , self-indulgent and remarkably ugly to look at , it 's ... like a series of pretentiously awful student films strung together into one feature-length horror ." - negative - 0.01
# "those outside show business will enjoy a close look at people they do n't really want to know ." - negative - 0.34
# "it 's the kind of movie you ca n't quite recommend because it is all windup and not much of a pitch , yet you ca n't bring yourself to dislike it ." - positive - 0.62
# "whether you 're moved and love it , or bored or frustrated by the film , you 'll still feel something ." - positive - 0.83
# "but he somehow pulls it off ." - negative - 0.01
# "an incredibly clever and superbly paced caper filled with scams within scams within scams ." - positive - 0.95
# "the spark of special anime magic here is unmistakable and hard to resist ." - positive - 0.99
# ...
# "must-see viewing for anyone involved in the high-tech industry ." - positive - 0.88
# "like old myths and wonder tales spun afresh ." - positive - 0.94
# "a beautiful and haunting examination of the stories we tell ourselves to make sense of the mundane horrors of the world ." - positive - 1.00
# "life is a crock -- or something like it ." - negative - 0.16
# "imagine if you will a tony hawk skating video interspliced with footage from behind enemy lines and set to jersey shore techno ." - negative - 0.10
# "it 's rare to find a film that dazzles the eye , challenges the brain , and satisfies our lust for fast-paced action , but minority report delivers all that and a whole lot more ." - positive - 0.95
# "it 's drained of life in an attempt to be sober and educational , and yet it 's so devoid of realism that its lack of whistles and bells just makes it obnoxious and stiff ." - negative - 0.01
# "... there are enough moments of heartbreaking honesty to keep one glued to the screen ." - positive - 0.99
# "it 's hard to tell with all the crashing and banging where the salesmanship ends and the movie begins ." - positive - 0.92
# "now it 's just tired ." - positive - 0.61
# "( u ) nrelentingly stupid ." - negative - 0.06
# "a work of astonishing delicacy and force ." - positive - 0.99
# "... as the story congeals you feel the pieces of the star wars saga falling into place in a way that makes your spine tingle with revelation and excitement ." - positive - 0.99
# "a fast-moving and remarkable film that appears destined to become a landmark in japanese animation ." - positive - 1.00
# "the film is itself a sort of cinematic high crime , one that brings military courtroom dramas down very , very low ." - negative - 0.01
# "the film meant well in its horse tale about freedom , but was n't able to reach the heart because it was too overbearing ." - negative - 0.46
# "offers that rare combination of entertainment and education ." - positive - 1.00
# "one of the best examples of how to treat a subject , you 're not fully aware is being examined , much like a photo of yourself you did n't know was being taken ." - positive - 0.99
# "an unbelievably fun film just a leading man away from perfection ." - positive - 1.00
# "if nothing else , this movie introduces a promising , unusual kind of psychological horror ." - positive - 0.94
# "it does succeed by following a feel-good formula with a winning style , and by offering its target audience of urban kids some welcome role models and optimism ." - positive - 0.94
# "going to the website may be just as fun ( and scary ) as going to the film ." - positive - 0.99
# "if this dud had been made in the '70s , it would have been called the hills have antlers and played for about three weeks in drive-ins ." - negative - 0.00
# "morton is , as usual , brilliant ." - positive - 0.99
# "an earnest , heartrending look at the divide between religious fundamentalists and their gay relatives ." - positive - 1.00
# "christians sensitive to a reductionist view of their lord as a luv-spreading dr. feelgood or omnipotent slacker will feel vastly more affronted than secularists , who might even praise god for delivering such an instant camp classic ." - positive - 0.99
# "but like bruce springsteen 's gone-to-pot asbury park , new jersey , this sad-sack waste of a movie is a city of ruins ." - negative - 0.00
# "with a story inspired by the tumultuous surroundings of los angeles , where feelings of marginalization loom for every dreamer with a burst bubble , the dogwalker has a few characters and ideas , but it never manages to put them on the same path ." - positive - 0.96
# "more honest about alzheimer 's disease , i think , than iris ." - positive - 0.98
# "maybe it 's asking too much , but if a movie is truly going to inspire me , i want a little more than this ." - negative - 0.00
# "none of these characters resembles anyone you 've ever met in real life , unless you happen to know annoyingly self-involved people who speak in glib sentences that could have only come from the pen of a screenwriter ." - negative - 0.08
# "just one more collection of penis , breast and flatulence gags in search of a story ." - negative - 0.01
# "but some unexpected zigs and zags help ." - positive - 1.00
# "by presenting an impossible romance in an impossible world , pumpkin dares us to say why either is impossible -- which forces us to confront what 's possible and what we might do to make it so ." - positive - 0.98
# "but it 's emotionally engrossing , too , thanks to strong , credible performances from the whole cast ." - positive - 1.00
# "a movie for 11-year-old boys with sports dreams of their own and the preteen girls who worship lil ' bow wow ." - positive - 0.93
# "skip work to see it at the first opportunity ." - negative - 0.01
# "there are slow and repetitive parts , but it has just enough spice to keep it interesting ." - negative - 0.06
# "safe conduct , however ambitious and well-intentioned , fails to hit the entertainment bull 's - eye ." - negative - 0.21
# "the way coppola professes his love for movies -- both colorful pop junk and the classics that unequivocally qualify as art -- is giddily entertaining ." - positive - 0.73
# "the latest installment in the pokemon canon , pokemon 4ever is surprising less moldy and trite than the last two , likely because much of the japanese anime is set in a scenic forest where pokemon graze in peace ." - negative - 0.00
# "a movie far more cynical and lazy than anything a fictitious charlie kaufman might object to ." - negative - 0.00
# "these are names to remember , in order to avoid them in the future ." - positive - 0.66
# "... with the candy-like taste of it fading faster than 25-cent bubble gum , i realized this is a throwaway movie that wo n't stand the test of time ." - negative - 0.15
# "it might as well have been problem child iv ." - negative - 0.02
# "all the performances are top notch and , once you get through the accents , all or nothing becomes an emotional , though still positive , wrench of a sit ." - positive - 0.57
# "his characters are engaging , intimate and the dialogue is realistic and greatly moving ." - positive - 1.00
# "national lampoon 's van wilder could be the worst thing to come out of national lampoon since class reunion" - negative - 0.01
# "( it 's ) a prison soccer movie starring charismatic tough guy vinnie jones , but it had too much spitting for me to enjoy ." - negative - 0.07
# "an intimate , good-humored ethnic comedy like numerous others but cuts deeper than expected ." - positive - 1.00
# "mocking them now is an exercise in pointlessness ." - negative - 0.38
# "liman , of swingers and go , makes his big-budget action film debut something of a clunker as he delivers a long , low-heat chase , interrupted by a middling car chase ." - positive - 0.87
# "two generations within one family test boundaries in this intelligent and restrained coming-of-age drama ." - positive - 0.84
# "hands down the year 's most thought-provoking film ." - positive - 0.99
# "and in this regard , on guard delivers ." - positive - 0.87
# "thrilling , provocative and darkly funny , this timely sci-fi mystery works on so many different levels that it not only invites , it demands repeated viewings ." - positive - 1.00
# "these are lives worth watching , paths worth following ." - positive - 0.98
# "the 3d images only enhance the film 's otherworldly quality , giving it a strange combo of you-are-there closeness with the disorienting unreality of the seemingly broken-down fourth wall of the movie screen ." - negative - 0.09
# "a slick , well-oiled machine , exquisitely polished and upholstered ." - positive - 1.00
# "a fairly by-the-books blend of action and romance with sprinklings of intentional and unintentional comedy ." - positive - 0.57
# "but here 's the real damn : it is n't funny , either ." - negative - 0.05
# "its characters are thinner than cardboard -- or even comic-book paper ." - negative - 0.08
# "... has virtually no script at all ..." - negative - 0.00
# "behind the snow games and lovable siberian huskies ( plus one sheep dog ) , the picture hosts a parka-wrapped dose of heart ." - negative - 0.35
# "roman coppola may never become the filmmaker his dad was , but heck -- few filmmakers will ." - positive - 0.79
# "the movie 's eventual success should be credited to dennis quaid , in fighting trim shape as an athlete as well as an actor" - positive - 0.86
# "the story drifts so inexorably into cliches about tortured ( and torturing ) artists and consuming but impossible love that you ca n't help but become more disappointed as each overwrought new sequence plods on ." - positive - 0.89
# "a gentle , compassionate drama about grief and healing ." - positive - 1.00
# "here , adrian lyne comes as close to profundity as he is likely to get ." - negative - 0.45
# "a tv episode inflated past its natural length ." - negative - 0.17
# "why he was given free reign over this project -- he wrote , directed , starred and produced -- is beyond me ." - negative - 0.27
# "begins as a promising meditation on one of america 's most durable obsessions but winds up as a slender cinematic stunt ." - positive - 1.00
# "it took 19 predecessors to get this ?" - positive - 0.69
# "binoche and magimel are perfect in these roles ." - positive - 1.00
# "the diversity of the artists represented , both in terms of style and ethnicity , prevents the proceedings from feeling repetitious , as does the appropriately brief 40-minute running time ." - negative - 0.20
# "a romantic comedy , yes , but one with characters who think and talk about their goals , and are working on hard decisions ." - positive - 0.97
# "at heart the movie is a deftly wrought suspense yarn whose richer shadings work as coloring rather than substance ." - positive - 0.93
# "feels like six different movies fighting each other for attention ." - negative - 0.30
# "director dirk shafer and co-writer greg hinton ride the dubious divide where gay porn reaches for serious drama ." - negative - 0.24
# "a movie that tries to fuse the two ` woods ' but winds up a bolly-holly masala mess ." - negative - 0.12
# "too bad , but thanks to some lovely comedic moments and several fine performances , it 's not a total loss ." - negative - 0.04
# "ordinary melodrama that is heavy on religious symbols but wafer-thin on dramatic substance" - negative - 0.00
# "fortunately for all involved , this movie is likely to disappear as quickly as an ice cube thrown into a pot of boiling water ." - negative - 0.01
# "the movie is a blast of educational energy , as bouncy animation and catchy songs escort you through the entire 85 minutes ." - negative - 0.49
# "rare is the ` urban comedy ' that even attempts the insight and honesty of this disarming indie ." - positive - 0.84
# "it 's also stupider ." - positive - 0.83
# "that zhang would make such a strainingly cute film -- with a blind orphan at its center , no less -- indicates where his ambitions have wandered ." - negative - 0.01
# "reggio falls victim to relying on the very digital technology that he fervently scorns , creating a meandering , inarticulate and ultimately disappointing film ." - negative - 0.01
# "we can see the wheels turning , and we might resent it sometimes , but this is still a nice little picture , made by bright and friendly souls with a lot of good cheer ." - positive - 1.00
# "the weight of water uses water as a metaphor for subconscious desire , but this leaky script barely stays afloat ." - negative - 0.03
# "a pleasant romantic comedy ." - positive - 1.00
# "the perfect film for those who like sick comedies that can be snide ." - positive - 0.99
# "a dreary , incoherent , self-indulgent mess of a movie in which a bunch of pompous windbags drone on inanely for two hours ... a cacophony of pretentious , meaningless prattle ." - negative - 0.00
# "full frontal is the antidote for soderbergh fans who think he 's gone too commercial since his two oscar nominated films in 2000" - negative - 0.10
# "son of the bride may be a good half-hour too long but comes replete with a flattering sense of mystery and quietness ." - negative - 0.13
# "technically , the film is about as interesting as an insurance commercial ." - positive - 0.97
# "well , it does go on forever ." - positive - 0.99
# "a graceful , contemplative film that gradually and artfully draws us into a world where the personal and the political get fatally intertwined ." - positive - 1.00
# "there 's no denying the elaborateness of the artist 's conceptions , nor his ability to depict them with outrageous elan , but really the whole series is so much pretentious nonsense , lavishly praised by those who equate obscurity with profundity ." - negative - 0.06
# "` dragonfly ' is a movie about a bus wreck that turns into a film wreck ." - negative - 0.47
# "there are films that try the patience of even the most cinema-besotted critic -- and this was one of them ." - positive - 0.70
# "the actors are forced to grapple with hazy motivations that never come into focus ." - negative - 0.45
# "when she speaks , her creepy egyptian demigod voice is as computer processed and overproduced as it was in her music ." - negative - 0.01
# "a soggy , cliche-bound epic-horror yarn that ends up being even dumber than its title ." - negative - 0.01
# "i saw knockaround guys yesterday , and already the details have faded like photographs from the spanish-american war ... it 's so unmemorable that it turned my ballpoint notes to invisible ink ." - negative - 0.03
# "there 's plenty of style in guillermo del toro 's sequel to the 1998 hit but why do we need 117 minutes to tell a tale that simply ca n't sustain more than 90 minutes ." - positive - 0.92
# "the unique tug-of-war with viewer expectations is undeniable , if not a pleasure in its own right ." - positive - 0.99
# "vividly conveys both the pitfalls and the pleasures of over-the-top love ." - positive - 0.86
# "ihops do n't pile on this much syrup ." - negative - 0.00
# "what kids will discover is a new collectible ." - positive - 0.79
# "when it really counts ... bloody sunday connects on a visceral level that transcends language ." - positive - 0.55
# "windtalkers blows this way and that , but there 's no mistaking the filmmaker in the tall grass , true to himself ." - positive - 0.56
# "... a polished and relatively sincere piece of escapism ." - positive - 0.90
# "the saturation bombing of reggio 's images and glass ' evocative music ... ultimately leaves viewers with the task of divining meaning ." - positive - 1.00
# "there 's not enough to sustain the comedy ." - negative - 0.13
# "formula 51 is so trite that even yu 's high-energy action stylings ca n't break through the stupor ." - negative - 0.00
# "despite a powerful portrayal by binoche , it 's a period romance that suffers from an overly deliberate pace and uneven narrative momentum ." - negative - 0.14
# "unless you are in dire need of a diesel fix , there is no real reason to see it ." - negative - 0.04
# "i kept thinking over and over again , ' i should be enjoying this . '" - negative - 0.02
# "the transporter is as lively and as fun as it is unapologetically dumb" - positive - 0.97
# "a real clunker ." - positive - 0.93
# "the pivotal narrative point is so ripe the film ca n't help but go soft and stinky ." - positive - 0.88
# "it 's amazingly perceptive in its subtle , supportive but unsentimental look at the marks family ." - positive - 1.00
# "legendary irish writer brendan behan 's memoir , borstal boy , has been given a loving screen transferral ." - positive - 0.89
# "the problem , it is with most of these things , is the script ." - negative - 0.02
# "it risks seeming slow and pretentious , because it thinks the gamble is worth the promise ." - negative - 0.04
# "take care of my cat offers a refreshingly different slice of asian cinema ." - positive - 1.00
# "davis has filled out his cast with appealing fresh faces ." - positive - 1.00
# "it represents better-than-average movie-making that does n't demand a dumb , distracted audience ." - negative - 0.01
